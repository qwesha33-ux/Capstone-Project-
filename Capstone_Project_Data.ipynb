# %% [markdown]
# <a href="https://colab.research.google.com/github/qwesha33-ux/Capstone-Project-/blob/main/Capstone_Project_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    'trial_name': [
        'STEP-1', 'STEP-2', 'STEP-3', 'STEP-4',
        'SURMOUNT-1', 'SURMOUNT-2', 'SURMOUNT-3', 'SURMOUNT-4',
        'SURMOUNT-5 (head-to-head)', 'SURMOUNT-5 (head-to-head)'
    ],
    'drug': [
        'Semaglutide', 'Semaglutide', 'Semaglutide', 'Semaglutide',
        'Tirzepatide', 'Tirzepatide', 'Tirzepatide', 'Tirzepatide',
        'Tirzepatide', 'Semaglutide'
    ],
    'drug_type': [
        'GLP-1 RA', 'GLP-1 RA', 'GLP-1 RA', 'GLP-1 RA',
        'GLP-1/GIP', 'GLP-1/GIP', 'GLP-1/GIP', 'GLP-1/GIP',
        'GLP-1/GIP', 'GLP-1 RA'
    ],
    'dose_mg': [2.4, 2.4, 2.4, 2.4, 15, 15, 15, 15, 15, 2.4],
    'duration_weeks': [68, 68, 68, 48, 72, 72, 72, 52, 72, 72],
    'n_participants': [1961, 1210, 611, 803, 2519, 938, 806, 670, 751, 750],
    'avg_weight_loss_pct': [14.9, 9.6, 16.0, 17.4, 20.9, 15.7, 21.1, 25.3, 20.2, 13.7],
    'avg_weight_loss_kg':  [15.3, 9.6, 16.0, 17.4, 22.5, 17.8, 24.3, 28.0, 22.8, 15.6],
    'pct_achieving_5pct_loss':  [86.4, 68.8, 88.7, 92.4, 91.0, 89.4, 92.0, 96.0, 92.5, 81.2],
    'pct_achieving_10pct_loss': [69.1, 46.2, 75.3, 79.0, 82.0, 74.2, 85.0, 91.0, 84.5, 68.5],
    'pct_achieving_15pct_loss': [50.5, 28.6, 58.3, 61.6, 63.0, 51.8, 67.0, 74.0, 63.5, 43.6],
    'hba1c_reduction_pct': [0, 1.6, 0, 0, 0, 2.0, 0, 0, 0, 0],
    'waist_circumference_reduction_cm': [7.7, 6.1, 8.6, 9.4, 13.9, 11.6, 14.2, 15.1, 12.5, 8.5],
    'discontinuation_pct': [7.0, 6.5, 5.8, 3.5, 8.9, 10.1, 7.8, 8.5, 8.2, 7.1],
    'nausea_pct':       [44.2, 42.3, 45.8, 44.0, 33.7, 33.4, 32.0, 31.5, 30.5, 41.8],
    'vomiting_pct':     [24.8, 22.7, 26.0, 25.0, 10.6, 10.2,  9.8,  9.5,  9.2, 23.5],
    'diarrhea_pct':     [29.7, 26.5, 31.0, 28.0, 23.0, 21.4, 22.0, 21.0, 20.8, 27.3],
    'constipation_pct': [24.2, 20.1, 25.7, 24.0, 17.6, 16.8, 15.9, 15.0, 15.4, 22.4],
    'fatigue_pct':      [11.0,  9.8, 12.0, 10.5, 11.0, 10.2, 10.0,  9.8, 10.1, 11.3],
    'population': [
        'Obesity without T2D', 'Obesity with T2D', 'Obesity + lifestyle', 'Obesity without T2D',
        'Obesity without T2D', 'Obesity with T2D', 'Obesity + lifestyle', 'Obesity without T2D',
        'Obesity without T2D (vs Sema)', 'Obesity without T2D (vs Tirz)'
    ],
    'year_published': [2021, 2021, 2021, 2021, 2022, 2023, 2023, 2023, 2024, 2024]
}

# %%
df = pd.DataFrame(data)

# %%
print("Dataset created!")
print(f"Shape: {df.shape[0]} rows x {df.shape[1]} columns\n")
print(df[['trial_name', 'drug', 'avg_weight_loss_pct', 'nausea_pct']].to_string(index=False))

print("\nData Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum().sum(), "missing values")
# Out:
# Dataset created!
# Shape: 10 rows x 21 columns
#
#                trial_name        drug  avg_weight_loss_pct  nausea_pct
#                    STEP-1 Semaglutide                 14.9        44.2
#                    STEP-2 Semaglutide                  9.6        42.3
#                    STEP-3 Semaglutide                 16.0        45.8
#                    STEP-4 Semaglutide                 17.4        44.0
#                SURMOUNT-1 Tirzepatide                 20.9        33.7
#                SURMOUNT-2 Tirzepatide                 15.7        33.4
#                SURMOUNT-3 Tirzepatide                 21.1        32.0
#                SURMOUNT-4 Tirzepatide                 25.3        31.5
# SURMOUNT-5 (head-to-head) Tirzepatide                 20.2        30.5
# SURMOUNT-5 (head-to-head) Semaglutide                 13.7        41.8
#
# Data Types:
# trial_name                           object
# drug                                 object
# ...

# %%
df.to_csv("glp1_comparison.csv", index=False)
print("\nSaved as glp1_comparison.csv")
# Out:
# Saved as glp1_comparison.csv
